# %% [markdown]
# <a href="https://colab.research.google.com/github/NoorRehman-Dev/EDA-On-Cricket-World-Cup-2024/blob/main/EDA_ON_ICC_MEN'S_T_20_WORLD_CUP_2024_DATASET.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Exploratory Data Analysis On World Cup 2024 Stats

# %% [markdown]
# **Importing Libraries**

# %%
import numpy as np     #Library for scientific computations
import pandas as pd    #Library for Data Manipulation
import seaborn as sns  #Library for Data visualization
import matplotlib.pyplot as plt #Library for Advance Data Visualization

# %% [markdown]
# ## Pre-Processing Data

# %% [markdown]
# **Loading Dataset**

# %%
df=pd.read_csv('/content/wk_stats_for_icc_mens_t20_world_cup_2024.csv')
df
# Out:
#                 Player                      Team  Mat  Inns  Dis  Ct  St  \
# 0              RR Pant                     India    8     8   14  13   1
# 1           Litton Das                Bangladesh    7     7    8   4   4
# 2             N Pooran               West Indies    7     7    8   8   0
# 3            Q de Kock              South africa    9     9    8   6   2
# 4           JC Buttler                   England    8     8    7   5   2
# 5            DP Conway               New Zealand    4     4    6   5   1
# 6   Rahmanullah Gurbaz               Afghanistan    8     8    6   6   0
# 7              S Movva                    Canada    3     3    5   5   0
# 8      Mohammad Rizwan                  Pakistan    4     3    4   4   0
# 9             ZE Green                   Namibia    4     4    4   3   1
# 10            MH Cross                  Scotland    4     3    3   2   1
# 11            K Doriga          Papua New Guinea    4     4    3   3   0
# ...

# %%
df.head()
# Out:
#        Player          Team  Mat  Inns  Dis  Ct  St  Max Dis Inns  Dis/Inn
# 0     RR Pant         India    8     8   14  13   1             3    1.750
# 1  Litton Das    Bangladesh    7     7    8   4   4             2    1.142
# 2    N Pooran   West Indies    7     7    8   8   0             2    1.142
# 3   Q de Kock  South africa    9     9    8   6   2             1    0.888
# 4  JC Buttler       England    8     8    7   5   2             2    0.875

# %%
df.tail()
# Out:
#            Player                      Team  Mat  Inns  Dis  Ct  St  \
# 18      S Ssesazi                    Uganda    4     4    1   1   0
# 19      Azam Khan                  Pakistan    1     1    0   0   0
# 20  Naseem Khushi                      Oman    2     1    0   0   0
# 21       MD Patel  United States of America    2     2    0   0   0
# 22    PS Athavale                      Oman    3     3    0   0   0
#
#     Max Dis Inns  Dis/Inn
# 18             1     0.25
# 19             0     0.00
# 20             0     0.00
# 21             0     0.00
# 22             0     0.00

# %%
df.columns
# Out:
# Index(['Player', 'Team', 'Mat', 'Inns', 'Dis', 'Ct', 'St', 'Max Dis Inns',
#        'Dis/Inn'],
#       dtype='object')

# %%
df.rename(columns={'Dis/Inn':'DisInn','Max Dis Inns':'MaxDis'})
# Out:
#                 Player                      Team  Mat  Inns  Dis  Ct  St  \
# 0              RR Pant                     India    8     8   14  13   1
# 1           Litton Das                Bangladesh    7     7    8   4   4
# 2             N Pooran               West Indies    7     7    8   8   0
# 3            Q de Kock              South africa    9     9    8   6   2
# 4           JC Buttler                   England    8     8    7   5   2
# 5            DP Conway               New Zealand    4     4    6   5   1
# 6   Rahmanullah Gurbaz               Afghanistan    8     8    6   6   0
# 7              S Movva                    Canada    3     3    5   5   0
# 8      Mohammad Rizwan                  Pakistan    4     3    4   4   0
# 9             ZE Green                   Namibia    4     4    4   3   1
# 10            MH Cross                  Scotland    4     3    3   2   1
# 11            K Doriga          Papua New Guinea    4     4    3   3   0
# ...

# %%
df.columns
# Out:
# Index(['Player', 'Team', 'Mat', 'Inns', 'Dis', 'Ct', 'St', 'Max Dis Inns',
#        'Dis/Inn'],
#       dtype='object')

# %%
df.isnull().sum()
# Out:
# Player          0
# Team            0
# Mat             0
# Inns            0
# Dis             0
# Ct              0
# St              0
# Max Dis Inns    0
# Dis/Inn         0
# dtype: int64

# %%
df.describe()
# Out:
#              Mat       Inns        Dis         Ct         St  Max Dis Inns  \
# count  23.000000  23.000000  23.000000  23.000000  23.000000     23.000000
# mean    4.695652   4.478261   3.869565   3.217391   0.652174      1.521739
# std     2.285026   2.371604   3.481175   3.132767   1.027295      0.897956
# min     1.000000   1.000000   0.000000   0.000000   0.000000      0.000000
# 25%     3.000000   3.000000   1.500000   1.000000   0.000000      1.000000
# 50%     4.000000   4.000000   3.000000   3.000000   0.000000      2.000000
# 75%     7.000000   7.000000   6.000000   5.000000   1.000000      2.000000
# max     9.000000   9.000000  14.000000  13.000000   4.000000      3.000000
#
#          Dis/Inn
# count  23.000000
# mean    0.748783
# std     0.528538
# min     0.000000
# 25%     0.339000
# 50%     0.750000
# 75%     1.071000
# max     1.750000

# %%
df.shape
# Out:
# (23, 9)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 23 entries, 0 to 22
# Data columns (total 9 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Player        23 non-null     object
#  1   Team          23 non-null     object
#  2   Mat           23 non-null     int64
#  3   Inns          23 non-null     int64
#  4   Dis           23 non-null     int64
#  5   Ct            23 non-null     int64
#  6   St            23 non-null     int64
#  7   Max Dis Inns  23 non-null     int64
#  8   Dis/Inn       23 non-null     float64
# dtypes: float64(1), int64(6), object(2)
# memory usage: 1.7+ KB

# %% [markdown]
# ## Outliers

# %%
sns.boxplot(x=df['Max Dis Inns'])
plt.show()

# %%
sns.boxplot(df['St'])
# Out:
# <Axes: ylabel='St'>

# %%
sns.boxplot(df['Ct'])
# Out:
# <Axes: ylabel='Ct'>

# %%
sns.boxplot(df['Dis/Inn'])
# Out:
# <Axes: ylabel='Dis/Inn'>

# %%
numeric_df=df.select_dtypes(include=[np.number])
non_numeric_df=df.select_dtypes(exclude=[np.number])
Q1=numeric_df.quantile(0.25)
Q3=numeric_df.quantile(0.75)
IQR=Q3-Q1
print(IQR)
# Out:
# Mat             4.000
# Inns            4.000
# Dis             4.500
# Ct              4.000
# St              1.000
# Max Dis Inns    1.000
# Dis/Inn         0.732
# dtype: float64

# %%
numeric_df.shape
# Out:
# (23, 7)

# %%
non_numeric_df.shape
# Out:
# (23, 2)

# %%
numeric_df=numeric_df[~((numeric_df<(Q1-1.5*IQR)) | (numeric_df>(Q1+1.5*IQR)))]
numeric_df.shape
# Out:
# (23, 7)

# %%
numeric_df=numeric_df.fillna(numeric_df.mean())

# %%
df=pd.concat([numeric_df,non_numeric_df],axis=1)

# %%
df
# Out:
#     Mat  Inns       Dis       Ct        St  Max Dis Inns  Dis/Inn  \
# 0     8     8  3.409091  2.52381  1.000000      1.380952   0.6153
# 1     7     7  8.000000  4.00000  0.263158      2.000000   1.1420
# 2     7     7  8.000000  2.52381  0.000000      2.000000   1.1420
# 3     9     9  8.000000  6.00000  0.263158      1.000000   0.8880
# 4     8     8  7.000000  5.00000  0.263158      2.000000   0.8750
# 5     4     4  6.000000  5.00000  1.000000      1.380952   0.6153
# 6     8     8  6.000000  6.00000  0.000000      2.000000   0.7500
# 7     3     3  5.000000  5.00000  0.000000      2.000000   0.6153
# 8     4     3  4.000000  4.00000  0.000000      2.000000   1.3330
# 9     4     4  4.000000  3.00000  1.000000      2.000000   1.0000
# 10    4     3  3.000000  2.00000  1.000000      2.000000   1.0000
# 11    4     4  3.000000  3.00000  0.000000      2.000000   0.7500
# 12    7     7  3.000000  3.00000  0.000000      2.000000   0.4280
# ...

# %%
df.isnull().sum()
# Out:
# Mat             0
# Inns            0
# Dis             0
# Ct              0
# St              0
# Max Dis Inns    0
# Dis/Inn         0
# Player          0
# Team            0
# dtype: int64

# %% [markdown]
# ## Data Visualization

# %%
sns.scatterplot(x=df['Player'],y=df['Ct'])
plt.title('Catches Taken by Player',weight='bold')
plt.xlabel('Player',weight='bold')
plt.ylabel('Catches',weight='bold')
plt.xticks(rotation=90)
plt.show()

# %%
sns.barplot(x=df['Player'],y=df['Dis'])
plt.title('Total Dismissals Made by the Player',weight='bold')
plt.xlabel('Player',weight='bold')
plt.ylabel('Dismissals',weight='bold')
plt.xticks(rotation=90)
plt.show()

# %%
numeric_df=numeric_df.corr()
sns.heatmap(numeric_df,cmap='BrBG',annot=True)
plt.show()
numeric_df
# Out:
#                    Mat      Inns       Dis        Ct        St  Max Dis Inns  \
# Mat           1.000000  0.999999  0.935749  0.940094 -0.957642      0.355171
# Inns          0.999999  1.000000  0.935797  0.940149 -0.957665      0.355226
# Dis           0.935749  0.935797  1.000000  0.999897 -0.997556      0.661391
# Ct            0.940094  0.940149  0.999897  1.000000 -0.998248      0.651574
# St           -0.957642 -0.957665 -0.997556 -0.998248  1.000000     -0.609274
# Max Dis Inns  0.355171  0.355226  0.661391  0.651574 -0.609274      1.000000
# Dis/Inn       0.247283  0.247360  0.572756  0.562118 -0.515808      0.993455
#
#                Dis/Inn
# Mat           0.247283
# Inns          0.247360
# Dis           0.572756
# Ct            0.562118
# St           -0.515808
# Max Dis Inns  0.993455
# Dis/Inn       1.000000

# %%
fig,ax=plt.subplots(figsize=(10,5))
sns.scatterplot(x=df['Player'],y=df['Inns'],ax=ax)
plt.title('Innings Played by Player',weight='bold')
plt.xlabel('Player',weight='bold')
plt.ylabel('Innings',weight='bold')
plt.xticks(rotation=90)
plt.show()
